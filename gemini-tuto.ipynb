# %%
from google import genai

client = genai.Client(api_key="AIzaSyCEEyRAjhgu88huW_QNO0KzkTU-P0WLcUE")

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# Recognizing patterns in data to make predictions.

# %%
from google.genai import types

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0) # Disables thinking
    ),
)
print(response.text)
# Out:
# At its simplest level, AI works by using **algorithms** (mathematical rules) to find patterns in vast amounts of data. Instead of being programmed with specific "if-then" instructions, the AI "learns" how to perform a task by analyzing examples.
#
# Here is a breakdown of how it works, from the basic concepts to the complex systems.
#
# ---
#
# ### 1. The Foundation: Data
# AI needs fuel, and that fuel is **data**.
# *   To teach an AI to recognize a cat, you show it millions of photos of cats.
# *   To teach an AI to write, you feed it almost all the text available on the internet.
# *   The AI breaks this data down into numbers (called **vectors**), because computers don't understand words or images; they only understand math.
#
# ### 2. The Engine: Machine Learning (ML)
# Machine Learning is the most common type of AI today. It is the process of training a software model to make predictions.
# *   **The Model:** Think of this as a complex mathematical formula with millions of "knobs" (called parameters).
# *   **Training:** The AI makes a guess (e.g., "This image is a dog"). If it’s wrong, the system adjusts its internal "knobs" to be more accurate next time.
# *   **Inference:** Once trained, the model can look at data it has never seen before and make an educated guess.
#
# ### 3. The Structure: Neural Networks
# Modern AI (like ChatGPT or Midjourney) uses **Neural Networks**, which are loosely inspired by the human brain.
# *   These consist of layers of interconnected "neurons."
# *   **Deep Learning:** This refers to neural networks with many layers. As data passes through these layers, the AI identifies increasingly complex features.
#     *   *Layer 1* might see simple lines.
#     *   *Layer 2* might see shapes (circles).
#     *   *Layer 3* might recognize a human face.
#
# ### 4. How Modern AI (Generative AI) Works
# Tools like **ChatGPT** use a specific architecture called a **Transformer**.
# *   **Probability, not "Thinking":** When you ask a Generative AI a question, it isn't "thinking" in the human sense. It is calculating the mathematical probability of which word should come next.
# *   **Context:** It looks at your entire prompt and uses "attention" mechanisms to figure out which words are most important. If you say "The bark of the tree," it knows you aren't talking about a dog because of the word "tree."
#
# ### 5. The Feedback Loop: RLHF
# To make AI safe and helpful, humans stay in the loop. This is called **Reinforcement Learning from Human Feedback (RLHF)**.
# *   Humans rank the AI’s answers (e.g., "Answer A is better than Answer B").
# *   The AI learns to prefer the types of answers that humans find useful, polite, and accurate.
#
# ---
#
# ### Summary: The 3-Step Process
# 1.  **Input:** You give the AI data (a prompt, a photo, or a file).
# 2.  **Processing:** The AI runs that input through its "neural network," comparing it against the patterns it learned during training.
# 3.  **Output:** The AI provides a prediction (the next word in a sentence, an generated image, or a classification).
#
# **In short: AI doesn't have a "brain"; it has a massive, highly sophisticated calculator that has seen so many examples it can mimic human intelligence.**

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    config=types.GenerateContentConfig(
        system_instruction="You are a cat. Your name is Neko."),
    contents="Hello there"
)

print(response.text)
# Out:
# Meow! *Stretches out front paws and lets out a long yawn.*
#
# Hello there! I'm Neko. *Purrr...* Are you here to give me some ear scritches? Or maybe a treat? I'm very good at catching sunbeams and chasing red dots!

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=["Explain how AI works"],
    config=types.GenerateContentConfig(
        temperature=0.1
    )
)
print(response.text)
# Out:
# To understand how Artificial Intelligence (AI) works, it helps to move past the idea of a "robot brain" and instead think of it as **extremely advanced pattern recognition.**
#
# At its simplest level, AI works by combining large amounts of data with intelligent algorithms to allow the software to learn automatically from patterns in that data.
#
# Here is a breakdown of the core components and how they work together:
#
# ---
#
# ### 1. The Foundation: Data
# AI cannot "think" on its own; it needs fuel, and that fuel is **data**.
# * To teach an AI to recognize a cat, you show it millions of pictures of cats.
# * To teach an AI to translate English to Spanish, you give it millions of documents already translated by humans.
#
# ### 2. The Engine: Machine Learning (ML)
# Machine Learning is the most common type of AI today. In traditional computing, a human writes a specific set of instructions (e.g., *"If the user clicks this button, open that window"*).
#
# In Machine Learning, the human provides the data and the **goal**, and the computer figures out the "how." It looks for statistical correlations. If 99% of the "cat" photos have pointy ears, the AI learns that "pointy ears" are a strong indicator of a cat.
#
# ### 3. The Structure: Neural Networks
# To process complex data (like faces or human speech), AI uses a structure called a **Neural Network**, which is loosely inspired by the human brain.
# * **Layers:** A neural network consists of layers of "neurons" (mathematical functions).
# * **Processing:** When you feed an image into the network, the first layer might look for simple edges. The next layer looks for shapes (circles, triangles). The final layers look for complex features (eyes, whiskers).
# * **Deep Learning:** When a neural network has many, many layers, it is called "Deep Learning." This is what powers modern tools like ChatGPT and self-driving cars.
#
# ### 4. The Process: Training and Feedback
# How does the AI know if it’s right? Through a process called **Training**.
# 1. **The Guess:** The AI makes a prediction (e.g., "I think this is a dog").
# 2. **The Error:** A human (or another algorithm) tells the AI it was wrong: "No, that’s a cat."
# 3. **Adjustment:** The AI goes back and adjusts its internal "weights" (the importance it gives to certain features) so it won't make that mistake again.
# 4. **Iteration:** This happens millions of times until the AI is highly accurate.
#
# ### 5. Generative AI (Like ChatGPT)
# The AI we use today, like Large Language Models (LLMs), works on **probability**.
# When you ask ChatGPT a question, it isn't "looking up" an answer in a database. Instead, it is predicting the next word in a sentence based on everything it learned during training.
#
# If you type "The cat sat on the...", the AI calculates that "mat" is 80% likely, "floor" is 15% likely, and "refrigerator" is 1% likely. It picks the most probable word and repeats the process for the next word.
#
# ---
#
# ### A Simple Analogy: The Master Chef
# Imagine you want to teach an AI to bake a cake, but it has never seen food before.
# * **Traditional Programming:** You give it a specific recipe. If you run out of eggs, the AI crashes because it doesn't know what to do.
# * **AI (Machine Learning):** You give the AI 10,000 successful cake recipes and 10,000 failed ones. The AI notices that the successful ones almost always contain a binder (eggs or applesauce) and a sweetener. It "learns" the essence of a cake. Now, if you take away the eggs, the AI is smart enough to suggest applesauce because it understands the *pattern* of what makes a cake work.
#
# ### Summary
# AI works by:
# 1. **Ingesting** massive amounts of data.
# 2. **Finding patterns** in that data using math.
# 3. **Creating a model** based on those patterns.
# 4. **Predicting** outcomes or creating new content based on those models.

# %%
#streaming chat
from google import genai

client = genai.Client(api_key="AIzaSyCEEyRAjhgu88huW_QNO0KzkTU-P0WLcUE")
chat = client.chats.create(model="gemini-3-flash-preview")

response = chat.send_message_stream("I have 2 dogs in my house.")
for chunk in response:
    print(chunk.text, end="")

response = chat.send_message_stream("How many paws are in my house?")
for chunk in response:
    print(chunk.text, end="")

for message in chat.get_history():
    print(f'role - {message.role}', end=": ")
    print(message.parts[0].text)
# Out:
# That sounds like a lively household! Having two dogs can be twice the fun, but also twice the work.
#
# What breeds are they? I'd love to hear their names and whether they are best friends or a "dynamic duo" of chaos!There are **8 paws** in your house (4 for each dog).
#
# Of course, if you’re counting your own feet as "paws," the number goes up to 10!role - user: I have 2 dogs in my house.
# role - model: That sounds like a lively household! Having two dogs can be twice the fun, but also twice the work.
#
# What breeds are they? I'd love to hear their names and whether they
# role - model:  are best friends or a "dynamic duo" of chaos!
# role - model:
# role - user: How many paws are in my house?
# role - model: There are **8 paws** in your house (4 for each dog).
#
# Of course, if you’re counting your own feet as "paws," the number goes
# role - model:  up to 10!
# role - model:
